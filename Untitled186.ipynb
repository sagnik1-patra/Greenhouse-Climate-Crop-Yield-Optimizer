# %%
import os, json, yaml, random, warnings
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

warnings.filterwarnings("ignore")

# ==========================================================
# 📂 PATHS
# ==========================================================
BASE_PATH = r"C:\Users\NXTWAVE\Downloads\Greenhouse Climate & Crop Yield Optimizer"
DATA_PATH = os.path.join(BASE_PATH, r"archive\20210703_greenhouse_data.csv")

MODEL_PATH   = os.path.join(BASE_PATH, "biosphere_model.h5")
SCALER_PATH  = os.path.join(BASE_PATH, "biosphere_scaler.pkl")
CONFIG_PATH  = os.path.join(BASE_PATH, "biosphere_config.yaml")
RESULTS_CSV  = os.path.join(BASE_PATH, "biosphere_results.csv")
RESULTS_JSON = os.path.join(BASE_PATH, "biosphere_prediction.json")

# ==========================================================
# 1️⃣ LOAD DATASET (SEMICOLON-SAFE)
# ==========================================================
print("[INFO] Loading dataset...")

try:
    df = pd.read_csv(DATA_PATH, sep=";", engine="python", on_bad_lines="skip")
    print("[INFO] ✅ Loaded with semicolon (;) delimiter")
except Exception as e:
    raise ValueError(f"❌ Could not parse dataset: {e}")

print(f"[INFO] Dataset shape: {df.shape}")
print(f"[INFO] Columns: {list(df.columns)}")

# --- Clean column names ---
df.columns = [c.strip().replace(" ", "_").lower() for c in df.columns]

# --- Drop empty rows/columns ---
df = df.dropna(axis=1, how="all")
df = df.dropna(axis=0, how="any").reset_index(drop=True)

# --- Convert to numeric where possible ---
for c in df.columns:
    df[c] = pd.to_numeric(df[c], errors="ignore")

numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
if len(numeric_cols) < 2:
    raise ValueError("❌ Not enough numeric columns detected for model training.")

print(f"[INFO] Numeric columns: {numeric_cols}")

# ==========================================================
# 2️⃣ FEATURES / TARGET
# ==========================================================
features = numeric_cols
target = features[-1]
X = df[features[:-1]].values
y = df[target].values.reshape(-1, 1)

# ==========================================================
# 3️⃣ SCALING
# ==========================================================
scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_x.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

with open(SCALER_PATH, "wb") as f:
    pickle.dump({"x": scaler_x, "y": scaler_y}, f)

# ==========================================================
# 4️⃣ CREATE LSTM SEQUENCES
# ==========================================================
def create_sequences(X, y, time_steps=10):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:(i + time_steps)])
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

TIME_STEPS = 10
X_seq, y_seq = create_sequences(X_scaled, y_scaled, TIME_STEPS)

train_size = int(0.8 * len(X_seq))
X_train, X_test = X_seq[:train_size], X_seq[train_size:]
y_train, y_test = y_seq[:train_size], y_seq[train_size:]

# ==========================================================
# 5️⃣ HYBRID OPTIMIZATION (PSO + GWO + HSA)
# ==========================================================
def objective(params):
    lr, units, dropout = params
    model = Sequential([
        LSTM(int(units), input_shape=(X_train.shape[1], X_train.shape[2])),
        Dropout(float(dropout)),
        Dense(1)
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), loss="mse")
    model.fit(X_train, y_train, epochs=5, batch_size=32, verbose=0)
    pred = model.predict(X_test)
    return mean_squared_error(y_test, pred)

def pso(num_particles=5, iterations=3):
    best_global, best_score = None, float("inf")
    particles = np.random.rand(num_particles, 3)
    for _ in range(iterations):
        for p in particles:
            lr = 0.0001 + p[0]*0.0099
            units = int(32 + p[1]*128)
            dropout = 0.1 + p[2]*0.4
            score = objective([lr, units, dropout])
            if score < best_score:
                best_score, best_global = score, [lr, units, dropout]
    return best_global

def gwo(base_params):
    lr, units, dropout = base_params
    candidates = []
    for _ in range(3):
        lr_c = lr * random.uniform(0.8, 1.2)
        units_c = units * random.uniform(0.8, 1.2)
        dropout_c = dropout * random.uniform(0.8, 1.2)
        candidates.append([lr_c, int(units_c), dropout_c])
    scores = [objective(c) for c in candidates]
    return candidates[np.argmin(scores)]

def hsa(params):
    lr, units, dropout = params
    lr_h = lr + random.uniform(-0.0005, 0.0005)
    units_h = int(units + random.uniform(-10, 10))
    dropout_h = max(0.1, min(0.5, dropout + random.uniform(-0.05, 0.05)))
    return [lr_h, units_h, dropout_h]

print("[INFO] Running Hybrid Optimization (PSO + GWO + HSA)...")
pso_best = pso()
gwo_best = gwo(pso_best)
final_params = hsa(gwo_best)
best_lr, best_units, best_dropout = final_params

print(f"[INFO] Best Hyperparams → lr={best_lr:.5f}, units={best_units}, dropout={best_dropout:.2f}")

# ==========================================================
# 6️⃣ FINAL LSTM TRAINING
# ==========================================================
model = Sequential([
    LSTM(best_units, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(best_dropout),
    Dense(1)
])
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=best_lr),
              loss="mse", metrics=["mae"])

history = model.fit(X_train, y_train, epochs=30, batch_size=32,
                    validation_split=0.1, verbose=1)

model.save(MODEL_PATH)
print(f"[INFO] Model saved → {MODEL_PATH}")

# ==========================================================
# 7️⃣ EVALUATION
# ==========================================================
y_pred = model.predict(X_test)
y_pred_inv = scaler_y.inverse_transform(y_pred)
y_test_inv = scaler_y.inverse_transform(y_test)

mae  = mean_absolute_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
r2   = r2_score(y_test_inv, y_pred_inv)
print(f"[RESULT] MAE={mae:.4f}, RMSE={rmse:.4f}, R²={r2:.4f}")

results_df = pd.DataFrame({"Actual": y_test_inv.flatten(),
                           "Predicted": y_pred_inv.flatten()})
results_df.to_csv(RESULTS_CSV, index=False)

with open(RESULTS_JSON, "w") as f:
    json.dump({
        "mae": mae, "rmse": rmse, "r2": r2,
        "best_params": {"lr": best_lr, "units": best_units, "dropout": best_dropout}
    }, f, indent=4)

# ==========================================================
# 8️⃣ VISUALIZATIONS
# ==========================================================
plt.figure(figsize=(10, 5))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Training & Validation Loss")
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(BASE_PATH, "biosphere_accuracy_graph.png"))

plt.figure(figsize=(6, 5))
sns.heatmap(df.corr(), annot=False, cmap="viridis")
plt.title("Feature Correlation Heatmap")
plt.tight_layout()
plt.savefig(os.path.join(BASE_PATH, "biosphere_heatmap.png"))

# ==========================================================
# 9️⃣ CONFIG YAML
# ==========================================================
config = {
    "dataset": DATA_PATH,
    "features": features[:-1],
    "target": target,
    "time_steps": TIME_STEPS,
    "optimizer": "Hybrid PSO + GWO + HSA",
    "best_hyperparams": {
        "learning_rate": float(best_lr),
        "units": int(best_units),
        "dropout": float(best_dropout)
    },
    "metrics": {"MAE": float(mae), "RMSE": float(rmse), "R2": float(r2)}
}

with open(CONFIG_PATH, "w") as f:
    yaml.dump(config, f)

# ==========================================================
# ✅ DONE
# ==========================================================
print("\n[INFO] ✅ Training complete. Artifacts saved in:")
print(f"  📦 {BASE_PATH}")
print("  ├── biosphere_model.h5")
print("  ├── biosphere_scaler.pkl")
print("  ├── biosphere_config.yaml")
print("  ├── biosphere_results.csv")
print("  ├── biosphere_prediction.json")
print("  ├── biosphere_accuracy_graph.png")
print("  └── biosphere_heatmap.png")
# Out:
# [INFO] Loading dataset...
# [INFO] ✅ Loaded with semicolon (;) delimiter
# [INFO] Dataset shape: (17562, 9)
# [INFO] Columns: ['id', 'greenhous_temperature_celsius', 'greenhouse_humidity_percentage', 'greenhouse_illuminance_lux', 'online_temperature_celsius', 'online_humidity_percentage', 'greenhouse_total_volatile_organic_compounds_ppb', 'greenhouse_equivalent_co2_ppm', 'created']
# [INFO] Numeric columns: ['id', 'online_humidity_percentage']
# [INFO] Running Hybrid Optimization (PSO + GWO + HSA)...
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\lstm.py:148: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 108/108 [==============================] - 1s 3ms/step
# 108/108 [==============================] - 1s 4ms/step
# 108/108 [==============================] - 1s 3ms/step
# 108/108 [==============================] - 1s 3ms/step
# 108/108 [==============================] - 1s 3ms/step
# 108/108 [==============================] - 1s 3ms/step
# 108/108 [==============================] - 1s 2ms/step
# 108/108 [==============================] - 1s 4ms/step
# 108/108 [==============================] - 1s 5ms/step
# 108/108 [==============================] - 1s 3ms/step
# 108/108 [==============================] - 1s 3ms/step
# 108/108 [==============================] - 1s 2ms/step
# 108/108 [==============================] - 1s 4ms/step
# 108/108 [==============================] - 1s 4ms/step
# 108/108 [==============================] - 1s 4ms/step
# 108/108 [==============================] - 1s 3ms/step
# 108/108 [==============================] - 1s 3ms/step
# 108/108 [==============================] - 1s 3ms/step
# [INFO] Best Hyperparams → lr=0.00069, units=54, dropout=0.31
# Epoch 1/30
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 386/386 [==============================] - 6s 9ms/step - loss: 0.0710 - mae: 0.2121 - val_loss: 0.0768 - val_mae: 0.2387
# Epoch 2/30
# 386/386 [==============================] - 3s 7ms/step - loss: 0.0477 - mae: 0.1819 - val_loss: 0.0885 - val_mae: 0.2503
# Epoch 3/30
# 386/386 [==============================] - 3s 7ms/step - loss: 0.0464 - mae: 0.1798 - val_loss: 0.0843 - val_mae: 0.2460
# Epoch 4/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0464 - mae: 0.1799 - val_loss: 0.0825 - val_mae: 0.2440
# Epoch 5/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0456 - mae: 0.1781 - val_loss: 0.0993 - val_mae: 0.2616
# Epoch 6/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0454 - mae: 0.1774 - val_loss: 0.0903 - val_mae: 0.2519
# Epoch 7/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0452 - mae: 0.1777 - val_loss: 0.0952 - val_mae: 0.2571
# Epoch 8/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0446 - mae: 0.1763 - val_loss: 0.0872 - val_mae: 0.2487
# Epoch 9/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0442 - mae: 0.1757 - val_loss: 0.0893 - val_mae: 0.2508
# Epoch 10/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0440 - mae: 0.1753 - val_loss: 0.0896 - val_mae: 0.2512
# Epoch 11/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0436 - mae: 0.1745 - val_loss: 0.0945 - val_mae: 0.2563
# Epoch 12/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0436 - mae: 0.1747 - val_loss: 0.0849 - val_mae: 0.2464
# Epoch 13/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0433 - mae: 0.1743 - val_loss: 0.0934 - val_mae: 0.2551
# Epoch 14/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0433 - mae: 0.1743 - val_loss: 0.0999 - val_mae: 0.2622
# Epoch 15/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0429 - mae: 0.1732 - val_loss: 0.0929 - val_mae: 0.2545
# Epoch 16/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0431 - mae: 0.1740 - val_loss: 0.0997 - val_mae: 0.2620
# Epoch 17/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0429 - mae: 0.1734 - val_loss: 0.0978 - val_mae: 0.2598
# Epoch 18/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0426 - mae: 0.1730 - val_loss: 0.1042 - val_mae: 0.2668
# Epoch 19/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0426 - mae: 0.1729 - val_loss: 0.0963 - val_mae: 0.2581
# Epoch 20/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0423 - mae: 0.1722 - val_loss: 0.1043 - val_mae: 0.2668
# Epoch 21/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0424 - mae: 0.1726 - val_loss: 0.0923 - val_mae: 0.2538
# Epoch 22/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0423 - mae: 0.1724 - val_loss: 0.1038 - val_mae: 0.2663
# Epoch 23/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0422 - mae: 0.1720 - val_loss: 0.1029 - val_mae: 0.2653
# Epoch 24/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0423 - mae: 0.1723 - val_loss: 0.1041 - val_mae: 0.2665
# Epoch 25/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0421 - mae: 0.1718 - val_loss: 0.0959 - val_mae: 0.2577
# Epoch 26/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0420 - mae: 0.1720 - val_loss: 0.1020 - val_mae: 0.2643
# Epoch 27/30
# 386/386 [==============================] - 2s 5ms/step - loss: 0.0418 - mae: 0.1714 - val_loss: 0.0980 - val_mae: 0.2601
# Epoch 28/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0419 - mae: 0.1714 - val_loss: 0.0941 - val_mae: 0.2558
# Epoch 29/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0419 - mae: 0.1716 - val_loss: 0.0984 - val_mae: 0.2605
# Epoch 30/30
# 386/386 [==============================] - 2s 6ms/step - loss: 0.0418 - mae: 0.1715 - val_loss: 0.0984 - val_mae: 0.2606
# [INFO] Model saved → C:\Users\NXTWAVE\Downloads\Greenhouse Climate & Crop Yield Optimizer\biosphere_model.h5
# 108/108 [==============================] - 1s 3ms/step
# [RESULT] MAE=14.8829, RMSE=18.9817, R²=-0.0938
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 204
#     201 plt.savefig(os.path.join(BASE_PATH, "biosphere_accuracy_graph.png"))
#     203 plt.figure(figsize=(6, 5))
# --> 204 sns.heatmap(df.corr(), annot=False, cmap="viridis")
#     205 plt.title("Feature Correlation Heatmap")
#     206 plt.tight_layout()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
#    2000     result = np.asarray(result, dtype=dtype)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: '2021-03-03 20:10:04'
